# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path().resolve().parent
sys.path.insert(0, str(PROJECT_ROOT))

# %%
from src.ultralytics_builder import UltralyticsDatasetBuilder

# %%
builder = UltralyticsDatasetBuilder(
    manifest_path="../data/artifacts/dataset_index.jsonl",
    classes_path="../data/classes.txt",
    out_dir="../datasets/fruitninja_yolo",
    train_split="train",
    val_split="test", 
    mode="copy",
)

data_yaml = builder.build()
# Out:
# [OK] Dataset Ultralytics em: ..\datasets\fruitninja_yolo
# [OK] train: 58 | val: 14
# [OK] data.yaml: ..\datasets\fruitninja_yolo\data.yaml

# %%
data_yaml
# Out:
# WindowsPath('../datasets/fruitninja_yolo/data.yaml')
