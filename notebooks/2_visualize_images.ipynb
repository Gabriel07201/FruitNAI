# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path().resolve().parent
sys.path.insert(0, str(PROJECT_ROOT))

# %%
from src.yolo_dataset import ManifestDataset, DatasetVisualizer

# %%
train_dataset = ManifestDataset(
    manifest_path="../data/artifacts/dataset_index.jsonl",
    split="train",
    classes_path="../data/classes.txt",
)

# %%
test_dataset = ManifestDataset(
    manifest_path="../data/artifacts/dataset_index.jsonl",
    split="test",
    classes_path="../data/classes.txt",
)

# %%
viz = DatasetVisualizer()

# %%
viz.plot_grid(train_dataset, indices=range(30), cols=6)

# %%
viz.plot_grid(test_dataset, indices=range(30), cols=6)
